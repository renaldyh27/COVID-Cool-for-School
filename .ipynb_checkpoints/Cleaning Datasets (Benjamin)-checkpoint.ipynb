# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import os

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# Benjamin: cumulative_enrollment, stats_sd
#
# Andrew: pubschools_info
#
# Alex: border_crossings

# %%
border_crossings_path = os.path.join('Datasets', 'border_crossings.csv')
border_crossings = pd.read_csv(border_crossings_path, low_memory=False)

cumulative_enrollment_path = os.path.join('Datasets', 'cumulative_enrollment.csv')
cumulative_enrollment = pd.read_csv(cumulative_enrollment, low_memory=False)

pubschools_info_path = os.path.join('Datasets', 'pubschools_info.csv')
pubschools_info = pd.read_csv(pubschools_info_path, low_memory=False)

stats_sd_path = os.path.join('Datasets', 'COVID_19_Statistics_San_Diego_County.csv')
stats_sd = pd.read_csv(stats_sd_path, low_memory=False)

#I'm having a bit of trouble loading this one in for some reason, I'll check it out later.
#age_stats_sd_path = os.path.join('Datasets', 'COVID-19_Age_Statistics_by_ZIP_Code')
#age_stats_sd = pd.read_csv(age_stats_sd_path, low_memory=False)

# %%
border_crossings
# Out:
#        Port Name                      Measure  January February    March  \
# 0        Andrade                  Pedestrians  113,254  115,655   75,638
# 1        Andrade  Personal Vehicle Passengers   87,090   82,972   70,204
# 2        Andrade            Personal Vehicles   46,520   44,277   39,473
# 3      Boquillas                  Pedestrians    2,585    3,036    2,629
# 4    Brownsville               Bus Passengers    4,467    3,072    2,572
# ..           ...                          ...      ...      ...      ...
# 131     Tornillo  Personal Vehicle Passengers   63,627   60,097   50,339
# 132     Tornillo            Personal Vehicles   34,183   32,824   29,055
# 133       Ysleta  Personal Vehicle Passengers      NaN      NaN  413,216
# 134       Ysleta            Personal Vehicles      NaN      NaN  248,433
# 135       Ysleta                       Trucks      NaN      NaN   53,842
#
#        April      May     June     July
# 0     11,190   23,217   21,886   19,720
# 1     29,720   30,962   29,780   30,439
# 2     19,102   18,634   17,926   18,480
# 3        NaN      NaN       13       10
# 4        405      776    1,052    1,200
# ..       ...      ...      ...      ...
# 131   22,536   38,308   45,866   47,205
# 132   15,255   23,711   27,197   27,787
# 133  137,820  212,568  252,160  260,127
# 134  104,032  149,358  170,431  175,029
# 135   32,299   29,914   47,765   54,839
#
# [136 rows x 9 columns]

# %%
cumulative_enrollment
# Out:
#        Port Name                      Measure  January February    March  \
# 0        Andrade                  Pedestrians  113,254  115,655   75,638
# 1        Andrade  Personal Vehicle Passengers   87,090   82,972   70,204
# 2        Andrade            Personal Vehicles   46,520   44,277   39,473
# 3      Boquillas                  Pedestrians    2,585    3,036    2,629
# 4    Brownsville               Bus Passengers    4,467    3,072    2,572
# ..           ...                          ...      ...      ...      ...
# 131     Tornillo  Personal Vehicle Passengers   63,627   60,097   50,339
# 132     Tornillo            Personal Vehicles   34,183   32,824   29,055
# 133       Ysleta  Personal Vehicle Passengers      NaN      NaN  413,216
# 134       Ysleta            Personal Vehicles      NaN      NaN  248,433
# 135       Ysleta                       Trucks      NaN      NaN   53,842
#
#        April      May     June     July
# 0     11,190   23,217   21,886   19,720
# 1     29,720   30,962   29,780   30,439
# 2     19,102   18,634   17,926   18,480
# 3        NaN      NaN       13       10
# 4        405      776    1,052    1,200
# ..       ...      ...      ...      ...
# 131   22,536   38,308   45,866   47,205
# 132   15,255   23,711   27,197   27,787
# 133  137,820  212,568  252,160  260,127
# 134  104,032  149,358  170,431  175,029
# 135   32,299   29,914   47,765   54,839
#
# [136 rows x 9 columns]

# %%
pubschools_info
# Out:
#                 CDSCode NCESDist NCESSchool StatusType   County  \
# 0        01100170000000  0691051    No Data     Active  Alameda
# 1        01100170109835  0691051      10546     Closed  Alameda
# 2        01100170112607  0691051      10947     Active  Alameda
# 3        01100170118489  0691051      12283     Closed  Alameda
# 4        01100170123968  0691051      12844     Active  Alameda
# ...                 ...      ...        ...        ...      ...
# 18136    58727695830039  0642350    No Data     Closed     Yuba
# 18137    58727695830070  0642350    No Data     Closed     Yuba
# 18138    58727695830120  0642350      08437     Closed     Yuba
# 18139    58727695838305  0642350      06930     Active     Yuba
# 18140  Total Records =     18140        NaN        NaN      NaN
#
#                                  District  \
# 0      Alameda County Office of Education
# 1      Alameda County Office of Education
# 2      Alameda County Office of Education
# 3      Alameda County Office of Education
# 4      Alameda County Office of Education
# ...                                   ...
# 18136                Wheatland Union High
# 18137                Wheatland Union High
# 18138                Wheatland Union High
# 18139                Wheatland Union High
# 18140                                 NaN
#
#                                               School  \
# 0                                            No Data
# 1                                FAME Public Charter
# 2             Envision Academy for Arts & Technology
# 3      Aspire California College Preparatory Academy
# 4            Community School for Creative Education
# ...                                              ...
# 18136                         Wheatland Continuation
# 18137                Wheatland Alternative Education
# 18138           Academy for Career Education Charter
# 18139                           Wheatland Union High
# 18140                                            NaN
#
#                                  Street                      StreetAbr  \
# 0                313 West Winton Avenue           313 West Winton Ave.
# 1      39899 Balentine Drive, Suite 335  39899 Balentine Dr., Ste. 335
# 2                   1515 Webster Street               1515 Webster St.
# 3                 2125 Jefferson Avenue            2125 Jefferson Ave.
# 4          2111 International Boulevard       2111 International Blvd.
# ...                                 ...                            ...
# 18136                        PO Box 398                     PO Box 398
# 18137                  801 Olive Street                  801 Olive St.
# 18138                  801 Olive Street                  801 Olive St.
# 18139               1010 Wheatland Road             1010 Wheatland Rd.
# 18140                               NaN                            NaN
#
#             City  ...  Virtual   Magnet YearRoundYN FederalDFCDistrictID  \
# 0        Hayward  ...  No Data  No Data     No Data              No Data
# 1         Newark  ...        P        N           N              No Data
# 2        Oakland  ...        N        N           N              0601614
# 3       Berkeley  ...        N        N           N              No Data
# 4        Oakland  ...        N        N           N              0601691
# ...          ...  ...      ...      ...         ...                  ...
# 18136  Wheatland  ...  No Data  No Data           N              No Data
# 18137  Wheatland  ...  No Data  No Data           N              No Data
# 18138  Wheatland  ...  No Data  No Data           N              No Data
# 18139  Wheatland  ...        N        N           N              No Data
# 18140        NaN  ...      NaN      NaN         NaN                  NaN
#
#         Latitude   Longitude   AdmFName AdmLName  \
# 0      37.658212  -122.09713    L Karen   Monroe
# 1      37.521436  -121.99391    No Data  No Data
# 2      37.804520  -122.26815  Manuschka  Michaud
# 3      37.868991  -122.27844    No Data  No Data
# 4      37.784648  -122.23863    Monique  Brinson
# ...          ...         ...        ...      ...
# 18136    No Data     No Data    No Data  No Data
# 18137    No Data     No Data    No Data  No Data
# 18138  39.010399  -121.42927    No Data  No Data
# 18139  38.998968  -121.45497         Cy    Olsen
# 18140        NaN         NaN        NaN      NaN
#
#                                                AdmEmail LastUpDate
# 0                                     lkmonroe@acoe.org  8/15/2020
# 1                                               No Data   9/1/2015
# 2                          mmichaud@envisionacademy.org  8/13/2020
# 3                                               No Data   7/1/2015
# 4      moniqueb@communityschoolforcreativeeducation.org  2/13/2019
# ...                                                 ...        ...
# 18136                                           No Data  6/24/1999
# 18137                                           No Data  6/24/1999
# 18138                                           No Data   7/2/2013
# 18139                          colsen@wheatlandhigh.org  8/13/2020
# 18140                                               NaN        NaN
#
# [18141 rows x 47 columns]

# %%
stats_sd
# Out:
#                 X             Y  objectid                    date     tests  \
# 0   -1.299488e+07  3.899796e+06        59  2020/03/11 08:00:00+00     123.0
# 1   -1.299488e+07  3.899796e+06        60  2020/03/12 08:00:00+00     147.0
# 2   -1.299488e+07  3.899796e+06        61  2020/03/13 08:00:00+00     273.0
# 3   -1.299488e+07  3.899796e+06        62  2020/03/14 08:00:00+00     288.0
# 4   -1.299488e+07  3.899796e+06        63  2020/03/15 08:00:00+00     313.0
# ..            ...           ...       ...                     ...       ...
# 184 -1.299488e+07  3.899796e+06       245  2020/09/06 08:00:00+00  880321.0
# 185 -1.299488e+07  3.899796e+06       246  2020/09/08 08:00:00+00  880321.0
# 186 -1.299488e+07  3.899796e+06       247  2020/09/09 08:00:00+00  897915.0
# 187 -1.299488e+07  3.899796e+06       248  2020/09/10 08:00:00+00  907123.0
# 188 -1.299488e+07  3.899796e+06       249  2020/09/11 08:00:00+00  915654.0
#
#      positives  hospitalized    icu  deaths  newcases  ...  age80_plus  \
# 0            5           NaN    NaN     NaN         1  ...         NaN
# 1           10           NaN    NaN     NaN         5  ...         NaN
# 2           19           NaN    NaN     NaN         9  ...         NaN
# 3           25          12.0    NaN     NaN         6  ...         NaN
# 4           37          10.0    NaN     NaN        12  ...         NaN
# ..         ...           ...    ...     ...       ...  ...         ...
# 184      40866        3225.0  777.0   708.0       216  ...      1330.0
# 185      41324        3237.0  773.0   721.0       247  ...      1343.0
# 186      41608        3253.0  775.0   725.0       284  ...      1351.0
# 187      41969        3266.0  775.0   730.0       361  ...      1355.0
# 188      42414        3278.0  777.0   734.0       445  ...      1363.0
#
#      ageunknow  age20_29  genderfemale  gendermale  gendeunk  age30_39  \
# 0          NaN       NaN           NaN         NaN       NaN       NaN
# 1          NaN       NaN           NaN         NaN       NaN       NaN
# 2          NaN       NaN           NaN         NaN       NaN       NaN
# 3          NaN       NaN           NaN         NaN       NaN       NaN
# 4          NaN       NaN           NaN         NaN       NaN       NaN
# ..         ...       ...           ...         ...       ...       ...
# 184       33.0   10364.0       20965.0     19788.0     113.0    7569.0
# 185       34.0   10493.0       21179.0     20035.0     110.0    7630.0
# 186       38.0   10542.0       21325.0     20173.0     110.0    7659.0
# 187       35.0   10637.0       21489.0     20368.0     112.0    7721.0
# 188       33.0   10758.0       21687.0     20616.0     111.0    7804.0
#
#                                    globalid  newtests  rolling_perc_pos_cases
# 0    {78698F35-A6E9-48CB-8C8D-67A70EC15C1D}       NaN                     NaN
# 1    {EFA2B0DB-A692-4632-8495-14B46E240096}       NaN                     NaN
# 2    {AA7DF18A-6303-4758-A5F1-9B9CD4388A92}      52.0                     NaN
# 3    {9A014068-714D-4FD4-B011-A16A1A49C07C}      14.0                     NaN
# 4    {DA54D0B2-3C90-4FF2-8090-BE3BDB8C1B4E}      25.0                     NaN
# ..                                      ...       ...                     ...
# 184  {EB1D16C5-D8A2-483F-AAE1-4B7518731E5C}    6788.0                4.312512
# 185  {407E67B6-999D-4CF4-9254-EAC378C41528}    6788.0                4.512304
# 186  {4C5A4AAD-D2E0-4ACF-B538-F3917A43155D}    8311.0                4.372067
# 187  {87BFD444-16C0-4465-975D-46027BDCBB3A}    9208.0                4.434672
# 188  {D6CC361E-530F-4501-9322-DCEA65FCB745}    8531.0                4.543988
#
# [189 rows x 26 columns]

# %% [markdown]
# Testing Out a change to work in the ben_cleaning branch
